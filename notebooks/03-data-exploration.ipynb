# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import h5py

# %%
b = "0500"
filename = f"../MA0035_4_s{b}_test.h5"
data = h5py.File(filename, 'r')
print(data.keys())
binlabels = data["binlabels"][:]
plt.hist(binlabels, bins=2)
# Out:
# <KeysViewHDF5 ['binlabels', 'data', 'labels']>
# (array([5000., 5000.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
labels = data["labels"][:]

# %%
plt.hist(labels, bins=100);

# %%
boundary = 1000
tlabels = np.zeros_like(labels, dtype=np.int8)
tlabels[labels<=boundary] = 0
tlabels[labels>boundary] = 1
plt.hist(tlabels, bins=2)
# Out:
# (array([5478., 4522.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
boundary = 5000
tlabels = np.zeros_like(labels, dtype=np.int8)
tlabels[labels<=boundary] = 0
tlabels[labels>boundary] = 1
plt.hist(tlabels, bins=2)
# Out:
# (array([6397., 3603.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
b = "5000"
filename = f"../MA0035_4_s{b}_test.h5"
data = h5py.File(filename, 'r')
binlabels = data["binlabels"][:]
plt.hist(binlabels, bins=2)
# Out:
# (array([5000., 5000.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
labels = data["labels"][:]
plt.hist(labels, bins=100);
