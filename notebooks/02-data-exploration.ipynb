# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import h5py

# %%
m = 0
filename = f"../MA0035_4_m{m}_test.h5"
data = h5py.File(filename, 'r')
binlabels = data["binlabels"][:]
plt.hist(binlabels, bins=2)
# Out:
# (array([1584., 8416.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
m = 1
filename = f"../MA0035_4_m{m}_test.h5"
data = h5py.File(filename, 'r')
binlabels = data["binlabels"][:]
plt.hist(binlabels, bins=2)
# Out:
# (array([3209., 6791.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
m = 2
filename = f"../MA0035_4_m{m}_test.h5"
data = h5py.File(filename, 'r')
binlabels = data["binlabels"][:]
plt.hist(binlabels, bins=2)
# Out:
# (array([4794., 5206.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
m = 3
filename = f"../MA0035_4_m{m}_test.h5"
data = h5py.File(filename, 'r')
binlabels = data["binlabels"][:]
plt.hist(binlabels, bins=2)
# Out:
# (array([5634., 4366.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
m = 5
filename = f"../MA0035_4_m{m}_test.h5"
data = h5py.File(filename, 'r')
binlabels = data["binlabels"][:]
plt.hist(binlabels, bins=2)
# Out:
# (array([7473., 2527.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
m = 8
filename = f"../MA0035_4_m{m}_test.h5"
data = h5py.File(filename, 'r')
binlabels = data["binlabels"][:]
plt.hist(binlabels, bins=2)
# Out:
# (array([8629., 1371.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)
